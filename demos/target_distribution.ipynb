# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %%
#Parameters to set
mu_x = 2.2
variance_x = 1

mu_y = -4
variance_y = 1.5

#Create grid and multivariate normal
x = np.linspace(-5,5,500)
y = np.linspace(-8,8,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos), cmap='viridis', linewidth=0, edgecolor='none')
ax.view_init(20, -135)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
zaxis_font = {'rotation':'30'}
ax.set_zlabel('Probability Density', **zaxis_font)
# label = ax.zaxis.label
# label.set_rotation(45)
ax.set_title('Distribution of fixed targets\' locations')
plt.show()
# plt.savefig("fixed-target-distribution.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_5273/3217585428.py:18: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#Parameters to set
mu_x = 5.5
variance_x = 7

mu_y = -10
variance_y = 10

#Create grid and multivariate normal
x = np.linspace(-12.5,12.5,500)
y = np.linspace(-20,20,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos), cmap='viridis', linewidth=0, edgecolor='none')
ax.view_init(20, -135)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
zaxis_font = {'rotation':'30'}
ax.set_zlabel('Probability Density', **zaxis_font)
# label = ax.zaxis.label
# label.set_rotation(45)
ax.set_title('Distribution of fixed targets\' locations')
plt.show()
# plt.savefig("fixed-target-distribution.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_14162/1152135232.py:18: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#Parameters to set
mu_x = -3
variance_x = 1

mu_y = 2
variance_y = 4.5

#Create grid and multivariate normal
x = np.linspace(-5,5,500)
y = np.linspace(-8,8,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos), cmap='plasma', linewidth=0, edgecolor='none')
ax.view_init(20, -135)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
zaxis_font = {'rotation':'30'}
ax.set_zlabel('Probability Density', **zaxis_font)
# label = ax.zaxis.label
# label.set_rotation(45)
ax.set_title('Distribution of mobile targets\' initial locations')
plt.show()
# plt.savefig("mobile-target-distribution.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_10047/3671902585.py:18: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#Parameters to set
mu_x = -7.5
variance_x = 3

mu_y = 5
variance_y = 30

#Create grid and multivariate normal
x = np.linspace(-12.5,12.5,500)
y = np.linspace(-20,20,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos), cmap='plasma', linewidth=0, edgecolor='none')
ax.view_init(20, -135)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
zaxis_font = {'rotation':'30'}
ax.set_zlabel('Probability Density', **zaxis_font)
# label = ax.zaxis.label
# label.set_rotation(45)
ax.set_title('Distribution of mobile targets\' initial locations')
plt.show()
# plt.savefig("mobile-target-distribution.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_10047/3214017275.py:18: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
for i in range(10):
    x, y = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]]).rvs()
    print("Target", i+1, " position: ", str(round(x,3)) + ", " + str(round(y,3)))
# Out:
# Target 1  position:  -7.213, -6.691
# Target 2  position:  -4.09, -10.382
# Target 3  position:  -7.304, -10.067
# Target 4  position:  -6.668, -11.576
# Target 5  position:  -7.922, -9.509
# Target 6  position:  -8.493, -7.639
# Target 7  position:  -8.842, -17.789
# Target 8  position:  -6.071, -15.397
# Target 9  position:  -6.175, -13.667
# Target 10  position:  -7.159, -11.981

# %%
num_targets = 10
locs = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]]).rvs(size=num_targets)
for i in range(num_targets):
    print("Target", i+1, " position: ", str(round(locs[i][0],3)) + ", " + str(round(locs[i][1],3)))
# Out:
# Target 1  position:  -7.608, -8.38
# Target 2  position:  -8.33, -12.366
# Target 3  position:  -8.128, -10.523
# Target 4  position:  -8.776, -10.814
# Target 5  position:  -6.179, -13.922
# Target 6  position:  -6.199, -9.759
# Target 7  position:  -9.175, -9.374
# Target 8  position:  -8.265, -15.295
# Target 9  position:  -10.011, -6.131
# Target 10  position:  -4.231, -13.764
