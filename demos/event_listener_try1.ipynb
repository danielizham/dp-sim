# %%
import olympe
import os
import subprocess
import tempfile
from olympe.media import (
    media_created,
    resource_created,
    media_removed,
    resource_removed,
    resource_downloaded,
    indexing_state,
    delete_media,
    download_media,
    download_media_thumbnail,
    MediaEvent,
)
from olympe.messages.camera import (
    set_camera_mode,
    set_photo_mode,
    take_photo,
    photo_progress,
)
from io import StringIO, BytesIO

# from logging import getLogger

# olympe.log.update_config(
#     {
#         "loggers": {
#             "olympe": {"level": "INFO", "handlers": ["console"]},
#             "urllib3": {"level": "DEBUG", "handlers": ["console"]},
#             __name__: {"level": "DEBUG", "handlers": ["console"]},
#         }
#     }
# )

# logger = getLogger(__name__)

DRONE_IP = os.environ.get("DRONE_IP", "10.202.0.1")
DRONE_MEDIA_PORT = os.environ.get("DRONE_MEDIA_PORT", "80")
img = None

# %%
class MediaEventListener(olympe.EventListener):
    def __init__(self, media):
        super().__init__(media, timeout=60)
        self._media = media
#         self._media_id = []
#         self._downloaded_resources = []
#         self.remote_resource_count = 0
#         self.local_resource_count = 0

    @olympe.listen_event(media_created())
    def onMediaCreated(self, event, scheduler):
        self._media(download_media(event.media_id))

#     @olympe.listen_event(resource_created())
#     def onResourceCreated(self, event, scheduler):
#         logger.info("resource_created {}".format(event.resource_id))

#     @olympe.listen_event(media_removed())
#     def onMediaRemoved(self, event, scheduler):
#         logger.info("media_removed {}".format(event.media_id))

#     @olympe.listen_event(resource_removed())
#     def onResourceRemoved(self, event, scheduler):
#         logger.info("resource_removed {}".format(event.resource_id))

    @olympe.listen_event(resource_downloaded())
    def onResourceDownloaded(self, event, scheduler):
        if event.is_thumbnail:
            return
        print(type(event))
        global img
        with open(event.download_path, "rb") as image_file:
            image_data = image_file.read()
            img = Image.open(BytesIO(image_data))

# #         print(type(image_file))
# #         print(type(image_data))
#         global img

#         logger.info(
#             "resource_downloaded {} {}".format(
#                 event.resource_id,
#                 event.data["download_path"],
#             )
#         )
#         self._downloaded_resources.append(
#             self._media.resource_info(resource_id=event.resource_id)
#         )

    @olympe.listen_event()
    def default(self, event, scheduler):
        if isinstance(event, MediaEvent):
            logger.info(event)

    def unsubscribe(self):
        self._media.wait_for_pending_downloads()
        # Sanity check 1/2: md5 checksum
        # The integrity check has already been performed by Olympe
        # For this example the following step demonstrate how to perform the media
        # integrity check afterward using the "md5summ --check *.md5" command.
        for resource in self._downloaded_resources:
            check = subprocess.run(
                ["md5sum", "--check", "{}.md5".format(resource.download_path)],
                stdout=subprocess.PIPE,
                cwd=os.path.dirname(resource.download_path),
            )
            stdout = check.stdout.decode().strip()
            if check.returncode == 0:
                logger.info("Integrity check: " + stdout)
            else:
                logger.error("Integrity check: " + stdout)
                super().unsubscribe()
                return

        # Sanity check 2/2: local downloaded resources equals the number of remote resources
        self.remote_resource_count = sum(
            map(
                lambda id_: len(self._media.resource_info(media_id=id_)), self._media_id
            )
        )
        self.local_resource_count = len(self._downloaded_resources)
        if self.local_resource_count != self.remote_resource_count:
            logger.error(
                "Downloaded {} resources instead of {}".format(
                    self.local_resource_count,
                    self.remote_resource_count,
                )
            )
            super().unsubscribe()
            return

        # OK then, we can now safely delete the remote media
        for media_id in self._media_id:
            delete = delete_media(media_id, _timeout=10)
            if not self._media(delete).wait().success():
                logger.error(
                    "Failed to delete media {} {}".format(media_id, delete.explain())
                )
        super().unsubscribe()

# %%
def setup_photo_burst_mode(drone):
    drone(set_camera_mode(cam_id=0, value="photo")).wait()
    # For the file_format: jpeg is the only available option
    # dng is not supported in burst mode
    drone(
        set_photo_mode(
            cam_id=0,
            mode="single",
            format="rectilinear",
            file_format="jpeg",
            burst="burst_14_over_1s",
            # the following parameters are ignored in photo burst mode but we
            # must provide valid values for them anyway
            bracketing="preset_1ev",
            capture_interval=5.0,
        )
    ).wait()

# %%
def main(drone, media=None):
    setup_photo_burst_mode(drone)
    if media is None:
        assert drone.media_autoconnect
        media = drone.media
    media.download_dir = tempfile.mkdtemp(prefix="olympe_media_example_")
    media.integrity_check = True
#     logger.info("waiting for media resources indexing...")
    if not media(indexing_state(state="indexed")).wait(_timeout=60).success():
#         logger.error("Media indexing timed out")
        return
#     logger.info("media resources indexed")
    with MediaEventListener(media) as media_listener:
        photo_saved = drone(photo_progress(result="photo_saved", _policy="wait"))
        drone(take_photo(cam_id=0)).wait()
        if not photo_saved.wait(_timeout=30).success():
#             logger.error("Photo not saved: {}".format(photo_saved.explain()))
            print("Photo not saved: {}".format(photo_saved.explain()))
            return
#     assert (
#         media_listener.remote_resource_count == 14
#     ), "remote resource count = {}".format(media_listener.remote_resource_count)
#     assert (
#         media_listener.local_resource_count == 14
#     ), "local resource count = {}".format(media_listener.local_resource_count)

# %%
def test_media():
    with olympe.Drone(
        DRONE_IP,
        media_autoconnect=False,
        media_port=DRONE_MEDIA_PORT,
        name="example_media_standalone",
    ) as drone:
        assert drone.connect()
        media = olympe.Media(
            f"{DRONE_IP}:{DRONE_MEDIA_PORT}", name="example_media_standalone"
        )
        assert media.connect()
        main(drone, media)
        assert media.shutdown()
        assert drone.disconnect()

# %%
test_media()
# Out:
# 2022-02-06 14:53:43,438 [INFO] 	olympe.example_media_standalone.backend - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:43,456 [INFO] 	olympe.example_media_standalone.backend - _do_create - device callbacks have been added to arsdk_ctrl
# 2022-02-06 14:53:43,483 [INFO] 	olympe.example_media_standalone.scheduler - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:43,518 [INFO] 	olympe.module_loader - add_package_root - ModuleLoader 'olympe.airsdk.example_media_standalone' root package has been registered
# 2022-02-06 14:53:43,542 [INFO] 	olympe.example_media_standalone.backend - _device_added_cb - DiscoveryNet: New device has been detected: 'ANAFI-0000000'
# 2022-02-06 14:53:43,548 [INFO] 	olympe.example_media_standalone.drone - _connecting_cb - Connecting to device: ANAFI-0000000
# 2022-02-06 14:53:43,552 [INFO] 	olympe.example_media_standalone.drone - _connect_impl - Connection in progress...
# 2022-02-06 14:53:43,554 [INFO] 	olympe.example_media_standalone.drone - _connected_cb - Connected to device: ANAFI-0000000
# 2022-02-06 14:53:43,555 [INFO] 	olympe.example_media_standalone.drone - _connected_cb - {'c2d_port': 2233,
#  'c2d_update_port': 51,
#  'c2d_user_port': 21,
#  'proto_v': 3,
#  'qos_mode': 0,
#  'status': 0}
# 2022-02-06 14:53:43,562 [INFO] 	olympe.example_media_standalone.drone - _create_command_interface - Command interface has been created
# 2022-02-06 14:53:43,566 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - common.Common.AllStates() has been sent to the device
# 2022-02-06 14:53:43,569 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.ending_behavior(ending_behavior='hovering')
# 2022-02-06 14:53:43,576 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.BatteryStateChanged(percent=100)
# 2022-02-06 14:53:43,807 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.ARLibsVersionsState.DeviceLibARCommandsVersion(version='4.0.0.4')
# 2022-02-06 14:53:43,812 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.BootId(bootId='64737A714170F98D7BDB9CE521340E2E')
# 2022-02-06 14:53:43,813 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.FlyingStateChanged(state='landed')
# 2022-02-06 14:53:43,815 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CalibrationState.MagnetoCalibrationRequiredState(required=0)
# 2022-02-06 14:53:43,817 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.AlertStateChanged(state='none')
# 2022-02-06 14:53:43,819 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='IMU', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,821 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='magnetometer', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,823 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='barometer', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,826 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='GPS', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,828 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='ultrasound', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,830 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.SensorsStatesListChanged(sensorName='vertical_camera', sensorState=1, list_flags='')
# 2022-02-06 14:53:43,832 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.alert(alert='power_level', level='none', list_flags='First')
# 2022-02-06 14:53:43,834 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.alert(alert='too_hot', level='none', list_flags='')
# 2022-02-06 14:53:43,836 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.alert(alert='too_cold', level='none', list_flags='Last')
# 2022-02-06 14:53:43,838 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.health(state_of_health=100)
# 2022-02-06 14:53:43,839 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.cycle_count(count=1)
# 2022-02-06 14:53:43,841 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - battery.serial(serial='')
# 2022-02-06 14:53:43,844 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GPSFixStateChanged(fixed=0)
# 2022-02-06 14:53:43,847 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SettingsState.MotorSoftwareVersionChanged(version='0.1.x.4')
# 2022-02-06 14:53:43,849 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SettingsState.MotorErrorStateChanged(motorIds=15, motorError='noError')
# 2022-02-06 14:53:43,851 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SettingsState.MotorFlightsStatusChanged(nbFlights=0, lastFlightDuration=0, totalFlightDuration=0)
# 2022-02-06 14:53:43,853 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SettingsState.MotorErrorLastErrorChanged(motorError='noError')
# 2022-02-06 14:53:43,855 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CalibrationState.MagnetoCalibrationStartedChanged(started=0)
# 2022-02-06 14:53:43,857 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.NavigateHomeStateChanged(state='unavailable', reason='disabled')
# 2022-02-06 14:53:43,858 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeAvailabilityChanged(type='TAKEOFF', available=0, list_flags='')
# 2022-02-06 14:53:43,861 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeAvailabilityChanged(type='PILOT', available=0, list_flags='')
# 2022-02-06 14:53:43,863 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeAvailabilityChanged(type='FIRST_FIX', available=0, list_flags='')
# 2022-02-06 14:53:43,865 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeAvailabilityChanged(type='FOLLOWEE', available=0, list_flags='')
# 2022-02-06 14:53:43,867 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeChosenChanged(type='TAKEOFF')
# 2022-02-06 14:53:43,869 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.home_type(type='takeoff')
# 2022-02-06 14:53:43,871 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.HomeChanged(latitude=500.0, longitude=500.0, altitude=500.0)
# 2022-02-06 14:53:43,872 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.takeoff_location(latitude=0.0, longitude=0.0, altitude=0.0, fixed_before_takeoff=0)
# 2022-02-06 14:53:43,874 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.home_reachability(status='unknown')
# 2022-02-06 14:53:43,876 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.rth_auto_trigger(reason='none', delay=0)
# 2022-02-06 14:53:43,878 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.ForcedLandingAutoTrigger(reason='NONE', delay=0)
# 2022-02-06 14:53:43,882 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - hand_land.state(state='idle')
# 2022-02-06 14:53:43,883 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.WindStateChanged(state='ok')
# 2022-02-06 14:53:43,885 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.VibrationLevelChanged(state='ok')
# 2022-02-06 14:53:43,887 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.MavlinkState.MavlinkFilePlayingStateChanged(state='stopped', filepath='', type='flightPlan')
# 2022-02-06 14:53:43,889 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - auto_follow.config(distance=0.0, elevation=0.0, azimuth=0.0)
# 2022-02-06 14:53:43,890 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - auto_follow.state(mode='none', behavior='idle')
# 2022-02-06 14:53:43,893 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - auto_look_at.state(mode='none', behavior='idle')
# 2022-02-06 14:53:43,895 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.state(mode='none', behavior='idle', animation='none', animation_available='')
# 2022-02-06 14:53:43,898 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.target_framing_position_changed(horizontal=0, vertical=0)
# 2022-02-06 14:53:43,900 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.target_image_detection_state(state='none')
# 2022-02-06 14:53:43,906 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.target_is_controller(state=0)
# 2022-02-06 14:53:43,908 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='look_at', missing_requirements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:43,911 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='geographic', missing_requirements='target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:43,913 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='relative', missing_requirements='target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:43,916 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='leash', missing_requirements='target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:43,918 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - animation.availability(values='')
# 2022-02-06 14:53:43,920 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='GPS', State=0, list_flags='')
# 2022-02-06 14:53:43,922 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='Calibration', State=1, list_flags='')
# 2022-02-06 14:53:43,924 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='TakeOff', State=1, list_flags='')
# 2022-02-06 14:53:43,926 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.AvailabilityStateChanged(AvailabilityState=0)
# 2022-02-06 14:53:43,928 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.PilotedPOI(latitude=0.0, longitude=0.0, altitude=0.0, status='UNAVAILABLE')
# 2022-02-06 14:53:43,930 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.PilotedPOIV2(latitude=0.0, longitude=0.0, altitude=0.0, mode='free_gimbal', status='UNAVAILABLE')
# 2022-02-06 14:53:43,933 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SoundState.AlertSound(state='stopped')
# 2022-02-06 14:53:43,935 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.state(state='not_available')
# 2022-02-06 14:53:43,937 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.counters(video_media_count=-1, photo_media_count=-1, video_resource_count=-1, photo_resource_count=-1)
# 2022-02-06 14:53:43,938 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.HoveringWarning(no_gps_too_dark=0, no_gps_too_high=0)
# 2022-02-06 14:53:43,940 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_mode(cam_id=0, mode='recording', list_flags='')
# 2022-02-06 14:53:43,942 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.hdr_setting(cam_id=0, value='inactive', list_flags='')
# 2022-02-06 14:53:43,945 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.hdr(cam_id=0, available='not_available', state='inactive', list_flags='')
# 2022-02-06 14:53:43,947 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_mode(cam_id=0, mode='single', format='full_frame', file_format='jpeg', burst='burst_14_over_1s', bracketing='preset_1ev', capture_interval=0.0, list_flags='')
# 2022-02-06 14:53:43,949 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_mode(cam_id=0, mode='standard', resolution='res_uhd_4k', framerate='fps_30', hyperlapse='ratio_15', bitrate=10000000, list_flags='')
# 2022-02-06 14:53:43,952 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.white_balance(cam_id=0, mode='automatic', temperature='t_1500', lock='inactive', list_flags='')
# 2022-02-06 14:53:43,956 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.exposure_settings(cam_id=0, mode='automatic', manual_shutter_speed='shutter_1_over_10000', manual_shutter_speed_capabilities='shutter_1_over_10000|shutter_1_over_8000|shutter_1_over_6400|shutter_1_over_5000|shutter_1_over_4000|shutter_1_over_3200|shutter_1_over_2500|shutter_1_over_2000|shutter_1_over_1600|shutter_1_over_1250|shutter_1_over_1000|shutter_1_over_800|shutter_1_over_640|shutter_1_over_500|shutter_1_over_400|shutter_1_over_320|shutter_1_over_240|shutter_1_over_200|shutter_1_over_160|shutter_1_over_120|shutter_1_over_100|shutter_1_over_80|shutter_1_over_60|shutter_1_over_50|shutter_1_over_40|shutter_1_over_30', manual_iso_sensitivity='iso_50', manual_iso_sensitivity_capabilities='iso_100|iso_160|iso_200|iso_320|iso_400|iso_640|iso_800|iso_1200|iso_1600|iso_2500|iso_3200', max_iso_sensitivity='iso_3200', max_iso_sensitivities_capabilities='iso_3200', metering_mode='standard', list_flags='')
# 2022-02-06 14:53:43,959 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.ev_compensation(cam_id=0, value='ev_0_00', list_flags='')
# 2022-02-06 14:53:43,961 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.style(cam_id=0, style='standard', saturation=0, saturation_min=-2, saturation_max=2, contrast=0, contrast_min=-2, contrast_max=2, sharpness=0, sharpness_min=-1, sharpness_max=1, list_flags='')
# 2022-02-06 14:53:43,963 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_state(cam_id=0, available='not_available', state='inactive', start_timestamp=0, list_flags='')
# 2022-02-06 14:53:43,965 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.MediaRecordState.VideoStateChangedV2(state='notAvailable', error='ok')
# 2022-02-06 14:53:43,966 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_state(cam_id=0, available='not_available', state='inactive', list_flags='')
# 2022-02-06 14:53:43,969 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.alignment_offsets(cam_id=0, min_bound_yaw=0.0, max_bound_yaw=0.0, current_yaw=0.0, min_bound_pitch=0.0, max_bound_pitch=0.0, current_pitch=0.0, min_bound_roll=0.0, max_bound_roll=0.0, current_roll=0.0, list_flags='')
# 2022-02-06 14:53:43,971 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.antiflicker_mode(mode='mode_50hz', value='mode_50hz')
# 2022-02-06 14:53:43,973 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_states(active_cameras=1)
# 2022-02-06 14:53:43,975 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.zoom_info(cam_id=0, available='available', high_quality_maximum_level=1.4000070095062256, maximum_level=2.9999840259552, list_flags='')
# 2022-02-06 14:53:43,977 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gimbal.axis_lock_state(gimbal_id=0, locked='', list_flags='')
# 2022-02-06 14:53:43,979 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - animation.state(type='none', percent=0)
# 2022-02-06 14:53:43,981 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.BoardIdChanged(id='0x0')
# 2022-02-06 14:53:43,982 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - precise_home.mode(mode='disabled')
# 2022-02-06 14:53:43,984 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - precise_home.state(state='unavailable')
# 2022-02-06 14:53:43,987 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - onboard_tracker.tracking_feature_availability(availability=0)
# 2022-02-06 14:53:43,989 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - onboard_tracker.target_tracking_state(target_id=0, cookie=0, state='tracking', list_flags='First|Last|Empty')
# 2022-02-06 14:53:43,991 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - stereo_vision_sensor.calibration_info(sensor_id=0, step_count=0, aspect_ratio=1.600000023841858)
# 2022-02-06 14:53:43,992 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - stereo_vision_sensor.calibration_state(sensor_id=0, state='ok')
# 2022-02-06 14:53:43,994 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - stereo_vision_sensor.calibration_step(sensor_id=0, step=0, vertex_lt_x=0.0, vertex_lt_y=0.0, vertex_rt_x=0.0, vertex_rt_y=0.0, vertex_lb_x=0.0, vertex_lb_y=0.0, vertex_rb_x=0.0, vertex_rb_y=0.0, angle_x=0.0, angle_y=0.0)
# 2022-02-06 14:53:43,997 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - piloting_style.style(style='standard')
# 2022-02-06 14:53:43,999 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mission.state(uid='', state='unavailable', unavailability_reason='broken', list_flags='')
# 2022-02-06 14:53:44,002 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gauge_fw_updater.status(diag='up_to_date', missing_requirements='', state='ready_to_prepare')
# 2022-02-06 14:53:44,004 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - dri.drone_id(type='ANSI_CTA_2063', value='1588E00000000000000')
# 2022-02-06 14:53:44,009 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - security_edition.log_storage_state(log_storage_state='enabled')
# 2022-02-06 14:53:44,017 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.CommonState.AllStatesChanged()
# 2022-02-06 14:53:44,024 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - common.Settings.AllSettings() has been sent to the device
# 2022-02-06 14:53:44,155 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.ProductSerialHighChanged(high='000000000')
# 2022-02-06 14:53:44,157 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.ProductSerialLowChanged(low='000000000')
# 2022-02-06 14:53:44,159 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.ProductVersionChanged(software='1.7.7', hardware='HW_00')
# 2022-02-06 14:53:44,162 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_capabilities(cam_id=0, model='main', exposure_modes='automatic|automatic_prefer_iso_sensitivity|automatic_prefer_shutter_speed|manual_iso_sensitivity|manual_shutter_speed|manual', exposure_lock_supported='supported', exposure_roi_lock_supported='supported', ev_compensations='ev_minus_3_00|ev_minus_2_67|ev_minus_2_33|ev_minus_2_00|ev_minus_1_67|ev_minus_1_33|ev_minus_1_00|ev_minus_0_67|ev_minus_0_33|ev_0_00|ev_0_33|ev_0_67|ev_1_00|ev_1_33|ev_1_67|ev_2_00|ev_2_33|ev_2_67|ev_3_00', white_balance_modes='automatic|incandescent|fluorescent|cool_white_fluorescent|sunny|cloudy|green_foliage|blue_sky', custom_white_balance_temperatures='', white_balance_lock_supported='supported', styles='standard|plog', camera_modes='recording|photo', hyperlapse_values='', bracketing_presets='', burst_values='', streaming_modes='', timelapse_interval_min=0.0, gpslapse_interval_min=0.0, auto_exposure_metering_modes='standard', list_flags='')
# 2022-02-06 14:53:44,165 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=0, recording_modes='standard', resolutions='res_dci_4k', framerates='fps_24', hdr='supported', list_flags='First')
# 2022-02-06 14:53:44,167 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=1, recording_modes='standard|hyperlapse', resolutions='res_uhd_4k|res_2_7k|res_1080p', framerates='fps_24|fps_25|fps_30', hdr='supported', list_flags='')
# 2022-02-06 14:53:44,168 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=2, recording_modes='slow_motion|high_framerate', resolutions='res_1080p|res_720p|res_1080p_sd', framerates='fps_48|fps_50|fps_60', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:44,172 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=3, recording_modes='slow_motion|high_framerate', resolutions='res_720p', framerates='', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:44,175 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=0, photo_modes='single|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='supported', list_flags='First')
# 2022-02-06 14:53:44,185 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=1, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:44,189 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=2, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:44,196 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=3, photo_modes='single|bracketing|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:44,199 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=4, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:44,203 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=5, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:44,213 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gimbal.gimbal_capabilities(gimbal_id=0, model='main', axes='pitch|roll', list_flags='')
# 2022-02-06 14:53:44,215 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.antiflicker_capabilities(supported_modes='off|mode_50hz|mode_60hz')
# 2022-02-06 14:53:44,218 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - leds.capabilities(supported_capabilities='')
# 2022-02-06 14:53:44,219 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - precise_home.capabilities(modes='disabled|standard')
# 2022-02-06 14:53:44,226 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - stereo_vision_sensor.capabilities(sensor_id=0, model='main', supported_features='')
# 2022-02-06 14:53:44,236 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - piloting_style.capabilities(styles='standard|camera_operated')
# 2022-02-06 14:53:44,244 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - dri.capabilities(supported_capabilities='on_off')
# 2022-02-06 14:53:44,246 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mission.capabilities(uid='', name='', desc='', version='', recipient_id=0, target_model_id=0, target_min_version='', target_max_version='', list_flags='First|Last|Empty')
# 2022-02-06 14:53:44,249 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.home_type_capabilities(values='takeoff|followee|custom|pilot')
# 2022-02-06 14:53:44,252 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - security_edition.capabilities(supported_capabilities='')
# 2022-02-06 14:53:44,254 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.MaxAltitudeChanged(current=4000.0, min=0.5, max=4000.0)
# 2022-02-06 14:53:44,257 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.MaxDistanceChanged(current=100.0, min=10.0, max=4000.0)
# 2022-02-06 14:53:44,261 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.NoFlyOverMaxDistanceChanged(shouldNotFlyOver=0)
# 2022-02-06 14:53:44,263 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.MaxTiltChanged(current=20.0, min=1.0, max=40.0)
# 2022-02-06 14:53:44,265 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SpeedSettingsState.MaxVerticalSpeedChanged(current=1.0, min=0.10000000149011612, max=4.0)
# 2022-02-06 14:53:44,267 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SpeedSettingsState.MaxRotationSpeedChanged(current=70.0, min=3.0, max=200.0)
# 2022-02-06 14:53:44,268 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SpeedSettingsState.MaxPitchRollRotationSpeedChanged(current=150.0, min=40.0, max=300.0)
# 2022-02-06 14:53:44,271 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.BankedTurnChanged(state=0)
# 2022-02-06 14:53:44,273 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SpeedSettingsState.HullProtectionChanged(present=0)
# 2022-02-06 14:53:44,275 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.ReturnHomeDelayChanged(delay=1)
# 2022-02-06 14:53:44,278 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.delay(delay=1, min=1, max=120)
# 2022-02-06 14:53:44,281 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.ReturnHomeMinAltitudeChanged(value=20.0, min=20.0, max=100.0)
# 2022-02-06 14:53:44,283 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.min_altitude(current=20.0, min=20.0, max=100.0)
# 2022-02-06 14:53:44,288 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.ending_behavior(ending_behavior='hovering')
# 2022-02-06 14:53:44,290 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.auto_trigger_mode(mode='on')
# 2022-02-06 14:53:44,293 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.state(state='unavailable', reason='disabled')
# 2022-02-06 14:53:44,295 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingSettingsState.MotionDetection(enabled=0)
# 2022-02-06 14:53:44,298 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.takeoff_location(latitude=0.0, longitude=0.0, altitude=0.0, fixed_before_takeoff=0)
# 2022-02-06 14:53:44,300 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.preferred_home_type(type='takeoff')
# 2022-02-06 14:53:44,302 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.HomeTypeChanged(type='TAKEOFF')
# 2022-02-06 14:53:44,304 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.ProductNameChanged(name='Parrot Drone')
# 2022-02-06 14:53:44,307 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - wifi.supported_security_types(types='open|wpa2')
# 2022-02-06 14:53:44,310 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - wifi.security_changed(type='open', key='', key_type='plain')
# 2022-02-06 14:53:44,315 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - wifi.ap_channel_changed(type='auto_all', band=-1, channel=255)
# 2022-02-06 14:53:44,322 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - wifi.country_changed(selection_mode='auto', code='FR')
# 2022-02-06 14:53:44,326 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - wifi.environment_changed(environment='outdoor')
# 2022-02-06 14:53:44,330 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gimbal.relative_attitude_bounds(gimbal_id=0, min_yaw=0.0, max_yaw=0.0, min_pitch=-135.0, max_pitch=105.0, min_roll=-38.0, max_roll=38.0, list_flags='')
# 2022-02-06 14:53:44,348 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gimbal.absolute_attitude_bounds(gimbal_id=0, min_yaw=0.0, max_yaw=0.0, min_pitch=-90.0, max_pitch=90.0, min_roll=0.0, max_roll=0.0, list_flags='')
# 2022-02-06 14:53:44,351 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - gimbal.max_speed(gimbal_id=0, min_bound_yaw=0.0, max_bound_yaw=0.0, current_yaw=0.0, min_bound_pitch=1.0, max_bound_pitch=180.0, current_pitch=14.0, min_bound_roll=0.0, max_bound_roll=0.0, current_roll=0.0, list_flags='')
# 2022-02-06 14:53:44,364 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.max_zoom_speed(cam_id=0, min=0.009999999776482582, max=10.0, current=0.3400000035762787, list_flags='')
# 2022-02-06 14:53:44,366 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.zoom_velocity_quality_degradation(cam_id=0, allowed=1, list_flags='')
# 2022-02-06 14:53:44,368 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.autorecord(cam_id=0, state='active', list_flags='')
# 2022-02-06 14:53:44,377 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - dri.dri_state(mode='disabled')
# 2022-02-06 14:53:44,379 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.ending_hovering_altitude(current=2.0, min=1.0, max=10.0)
# 2022-02-06 14:53:44,381 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.SettingsState.ProductGPSVersionChanged(software='', hardware='')
# 2022-02-06 14:53:44,383 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.SettingsState.AllSettingsChanged()
# 2022-02-06 14:53:44,386 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - mission.custom_msg_enable() has been sent to the device
# 2022-02-06 14:53:44,562 [INFO] 	olympe.example_media_standalone.drone - _on_connected - <olympe.arsdkng.cmd_itf.ConnectedEvent object at 0x7f669b2f7520>
# 2022-02-06 14:53:44,567 [INFO] 	olympe.example_media_standalone.pdraw - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:44,581 [INFO] 	olympe.example_media_standalone.pdraw - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:44,594 [INFO] 	olympe.example_media_standalone.media - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:44,599 [INFO] 	olympe.example_media_standalone.scheduler - _create_pomp_loop - Creating pomp loop
# 2022-02-06 14:53:44,640 [ERROR] 	olympe.example_media_standalone.media - _get_all_media - 541 Server Error: Media Not Yet Indexed for url: http://10.202.0.1:80/api/v1/media/medias
# 2022-02-06 14:53:44,644 [WARNING] 	olympe.example_media_standalone.media - _websocket_connect_cb - Media are not yet indexed
# 2022-02-06 14:53:44,661 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - camera.set_camera_mode(cam_id=0, value='photo') has been sent to the device
# 2022-02-06 14:53:44,663 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.antiflicker_capabilities(supported_modes='off|mode_50hz|mode_60hz')
# 2022-02-06 14:53:44,984 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_capabilities(cam_id=0, model='main', exposure_modes='automatic|automatic_prefer_iso_sensitivity|automatic_prefer_shutter_speed|manual_iso_sensitivity|manual_shutter_speed|manual', exposure_lock_supported='supported', exposure_roi_lock_supported='supported', ev_compensations='ev_minus_3_00|ev_minus_2_67|ev_minus_2_33|ev_minus_2_00|ev_minus_1_67|ev_minus_1_33|ev_minus_1_00|ev_minus_0_67|ev_minus_0_33|ev_0_00|ev_0_33|ev_0_67|ev_1_00|ev_1_33|ev_1_67|ev_2_00|ev_2_33|ev_2_67|ev_3_00', white_balance_modes='automatic|incandescent|fluorescent|cool_white_fluorescent|sunny|cloudy|green_foliage|blue_sky', custom_white_balance_temperatures='', white_balance_lock_supported='supported', styles='standard|plog', camera_modes='recording|photo', hyperlapse_values='', bracketing_presets='', burst_values='', streaming_modes='', timelapse_interval_min=0.0, gpslapse_interval_min=0.0, auto_exposure_metering_modes='standard', list_flags='')
# 2022-02-06 14:53:44,987 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=0, recording_modes='standard', resolutions='res_dci_4k', framerates='fps_24', hdr='supported', list_flags='First')
# 2022-02-06 14:53:44,989 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=1, recording_modes='standard|hyperlapse', resolutions='res_uhd_4k|res_2_7k|res_1080p', framerates='fps_24|fps_25|fps_30', hdr='supported', list_flags='')
# 2022-02-06 14:53:44,995 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=2, recording_modes='slow_motion|high_framerate', resolutions='res_1080p|res_720p|res_1080p_sd', framerates='fps_48|fps_50|fps_60', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:44,998 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=3, recording_modes='slow_motion|high_framerate', resolutions='res_720p', framerates='', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:45,003 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=0, photo_modes='single|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='supported', list_flags='First')
# 2022-02-06 14:53:45,007 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=1, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,013 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=2, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,016 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=3, photo_modes='single|bracketing|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,023 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=4, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,026 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=5, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:45,035 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_mode(cam_id=0, mode='photo', list_flags='')
# 2022-02-06 14:53:45,041 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.exposure_settings(cam_id=0, mode='automatic', manual_shutter_speed='shutter_1_over_10000', manual_shutter_speed_capabilities='shutter_1_over_10000|shutter_1_over_8000|shutter_1_over_6400|shutter_1_over_5000|shutter_1_over_4000|shutter_1_over_3200|shutter_1_over_2500|shutter_1_over_2000|shutter_1_over_1600|shutter_1_over_1250|shutter_1_over_1000|shutter_1_over_800|shutter_1_over_640|shutter_1_over_500|shutter_1_over_400|shutter_1_over_320|shutter_1_over_240|shutter_1_over_200|shutter_1_over_160|shutter_1_over_120|shutter_1_over_100|shutter_1_over_80|shutter_1_over_60|shutter_1_over_50|shutter_1_over_40|shutter_1_over_30|shutter_1_over_25|shutter_1_over_15|shutter_1_over_10|shutter_1_over_8|shutter_1_over_6|shutter_1_over_4|shutter_1_over_3|shutter_1_over_2|shutter_1_over_1_5|shutter_1', manual_iso_sensitivity='iso_50', manual_iso_sensitivity_capabilities='iso_100|iso_160|iso_200|iso_320|iso_400|iso_640|iso_800|iso_1200|iso_1600|iso_2500|iso_3200', max_iso_sensitivity='iso_3200', max_iso_sensitivities_capabilities='iso_3200', metering_mode='standard', list_flags='')
# 2022-02-06 14:53:45,046 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.antiflicker_capabilities(supported_modes='off|mode_50hz|mode_60hz')
# 2022-02-06 14:53:45,050 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_capabilities(cam_id=0, model='main', exposure_modes='automatic|automatic_prefer_iso_sensitivity|automatic_prefer_shutter_speed|manual_iso_sensitivity|manual_shutter_speed|manual', exposure_lock_supported='supported', exposure_roi_lock_supported='supported', ev_compensations='ev_minus_3_00|ev_minus_2_67|ev_minus_2_33|ev_minus_2_00|ev_minus_1_67|ev_minus_1_33|ev_minus_1_00|ev_minus_0_67|ev_minus_0_33|ev_0_00|ev_0_33|ev_0_67|ev_1_00|ev_1_33|ev_1_67|ev_2_00|ev_2_33|ev_2_67|ev_3_00', white_balance_modes='automatic|incandescent|fluorescent|cool_white_fluorescent|sunny|cloudy|green_foliage|blue_sky', custom_white_balance_temperatures='', white_balance_lock_supported='supported', styles='standard|plog', camera_modes='recording|photo', hyperlapse_values='', bracketing_presets='', burst_values='', streaming_modes='', timelapse_interval_min=0.0, gpslapse_interval_min=0.0, auto_exposure_metering_modes='standard', list_flags='')
# 2022-02-06 14:53:45,055 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=0, recording_modes='standard', resolutions='res_dci_4k', framerates='fps_24', hdr='supported', list_flags='First')
# 2022-02-06 14:53:45,059 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=1, recording_modes='standard|hyperlapse', resolutions='res_uhd_4k|res_2_7k|res_1080p', framerates='fps_24|fps_25|fps_30', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,062 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=2, recording_modes='slow_motion|high_framerate', resolutions='res_1080p|res_720p|res_1080p_sd', framerates='fps_48|fps_50|fps_60', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,065 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=3, recording_modes='slow_motion|high_framerate', resolutions='res_720p', framerates='', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:45,068 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=0, photo_modes='single|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='supported', list_flags='First')
# 2022-02-06 14:53:45,075 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=1, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,078 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=2, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,082 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=3, photo_modes='single|bracketing|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,090 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=4, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,092 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=5, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:45,095 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_state(cam_id=0, available='not_available', state='inactive', start_timestamp=0, list_flags='')
# 2022-02-06 14:53:45,102 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.MediaRecordState.VideoStateChangedV2(state='notAvailable', error='ok')
# 2022-02-06 14:53:45,106 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_state(cam_id=0, available='not_available', state='inactive', list_flags='')
# 2022-02-06 14:53:45,110 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.zoom_info(cam_id=0, available='not_available', high_quality_maximum_level=1.0, maximum_level=1.0, list_flags='')
# 2022-02-06 14:53:45,113 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - camera.set_photo_mode(cam_id=0, mode='single', format='rectilinear', file_format='jpeg', burst='burst_14_over_1s', bracketing='preset_1ev', capture_interval=5.0) has been sent to the device
# 2022-02-06 14:53:45,308 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.antiflicker_capabilities(supported_modes='off|mode_50hz|mode_60hz')
# 2022-02-06 14:53:45,315 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.camera_capabilities(cam_id=0, model='main', exposure_modes='automatic|automatic_prefer_iso_sensitivity|automatic_prefer_shutter_speed|manual_iso_sensitivity|manual_shutter_speed|manual', exposure_lock_supported='supported', exposure_roi_lock_supported='supported', ev_compensations='ev_minus_3_00|ev_minus_2_67|ev_minus_2_33|ev_minus_2_00|ev_minus_1_67|ev_minus_1_33|ev_minus_1_00|ev_minus_0_67|ev_minus_0_33|ev_0_00|ev_0_33|ev_0_67|ev_1_00|ev_1_33|ev_1_67|ev_2_00|ev_2_33|ev_2_67|ev_3_00', white_balance_modes='automatic|incandescent|fluorescent|cool_white_fluorescent|sunny|cloudy|green_foliage|blue_sky', custom_white_balance_temperatures='', white_balance_lock_supported='supported', styles='standard|plog', camera_modes='recording|photo', hyperlapse_values='', bracketing_presets='', burst_values='', streaming_modes='', timelapse_interval_min=0.0, gpslapse_interval_min=0.0, auto_exposure_metering_modes='standard', list_flags='')
# 2022-02-06 14:53:45,321 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=0, recording_modes='standard', resolutions='res_dci_4k', framerates='fps_24', hdr='supported', list_flags='First')
# 2022-02-06 14:53:45,324 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=1, recording_modes='standard|hyperlapse', resolutions='res_uhd_4k|res_2_7k|res_1080p', framerates='fps_24|fps_25|fps_30', hdr='supported', list_flags='')
# 2022-02-06 14:53:45,328 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=2, recording_modes='slow_motion|high_framerate', resolutions='res_1080p|res_720p|res_1080p_sd', framerates='fps_48|fps_50|fps_60', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:45,332 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.recording_capabilities(id=3, recording_modes='slow_motion|high_framerate', resolutions='res_720p', framerates='', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:45,338 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=0, photo_modes='single|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='supported', list_flags='First')
# 2022-02-06 14:53:45,340 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=1, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:46,282 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=2, photo_modes='single|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='supported', list_flags='')
# 2022-02-06 14:53:46,291 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=3, photo_modes='single|bracketing|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='dng_jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:46,293 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=4, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='full_frame', photo_file_formats='jpeg', hdr='not_supported', list_flags='')
# 2022-02-06 14:53:46,296 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_capabilities(id=5, photo_modes='single|bracketing|burst|time_lapse|gps_lapse', photo_formats='rectilinear', photo_file_formats='jpeg', hdr='not_supported', list_flags='Last')
# 2022-02-06 14:53:46,299 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_mode(cam_id=0, mode='single', format='rectilinear', file_format='jpeg', burst='burst_14_over_1s', bracketing='preset_1ev', capture_interval=5.0, list_flags='')
# 2022-02-06 14:53:46,304 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.zoom_info(cam_id=0, available='available', high_quality_maximum_level=1.0, maximum_level=2.999976396560669, list_flags='')
# 2022-02-06 14:53:46,971 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GPSFixStateChanged(fixed=1)
# 2022-02-06 14:53:47,294 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.NumberOfSatelliteChanged(numberOfSatellite=12)
# 2022-02-06 14:53:47,297 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.PilotingState.HeadingLockedStateChanged(state='ok')
# 2022-02-06 14:53:47,299 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='look_at', missing_requirements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:47,301 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='geographic', missing_requirements='drone_calibrated|drone_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:47,304 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='relative', missing_requirements='drone_calibrated|drone_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:47,306 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - follow_me.mode_info(mode='leash', missing_requirements='drone_calibrated|drone_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|target_good_speed|drone_close_enough', improvements='drone_calibrated|drone_gps_good_accuracy|target_gps_good_accuracy|target_barometer_ok|drone_far_enough|drone_high_enough|image_detection|target_good_speed|drone_close_enough', list_flags='')
# 2022-02-06 14:53:47,308 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeAvailabilityChanged(type='FIRST_FIX', available=1, list_flags='')
# 2022-02-06 14:53:47,310 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSState.HomeTypeChosenChanged(type='FIRST_FIX')
# 2022-02-06 14:53:47,312 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.HomeChanged(latitude=48.87890000000001, longitude=2.3677785, altitude=2.0)
# 2022-02-06 14:53:47,316 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - rth.takeoff_location(latitude=48.87890000000001, longitude=2.3677785, altitude=2.0, fixed_before_takeoff=0)
# 2022-02-06 14:53:47,319 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.MavlinkState.MavlinkFilePlayingStateChanged(state='stopped', filepath='', type='flightPlan')
# 2022-02-06 14:53:47,323 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='GPS', State=1, list_flags='')
# 2022-02-06 14:53:47,330 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='Calibration', State=1, list_flags='')
# 2022-02-06 14:53:47,334 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.ComponentStateListChanged(component='TakeOff', State=1, list_flags='')
# 2022-02-06 14:53:47,339 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - common.FlightPlanState.AvailabilityStateChanged(AvailabilityState=1)
# 2022-02-06 14:53:47,344 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:48,615 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:49,438 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:49,498 [INFO] 	olympe.example_media_standalone.drone - _link_quality_cb - Link quality: tx=55, rx=100, rx_useful=97
# 2022-02-06 14:53:49,801 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:50,438 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:51,174 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:51,430 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.capabilities(supported_features='format_when_ready_allowed|format_result_evt_supported|format_progress_evt_supported|encryption_supported')
# 2022-02-06 14:53:51,646 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.supported_formatting_types(supported_types='full|quick')
# 2022-02-06 14:53:51,648 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.capabilities(supported_features='format_when_ready_allowed|format_result_evt_supported|format_progress_evt_supported|encryption_supported')
# 2022-02-06 14:53:51,656 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.supported_formatting_types(supported_types='full|quick')
# 2022-02-06 14:53:51,661 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.state(physical_state='undetected', file_system_state='unknown', attribute='', monitor_enabled=0, monitor_period=0)
# 2022-02-06 14:53:51,667 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.info(name='', capacity=0)
# 2022-02-06 14:53:51,670 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - user_storage.state(physical_state='undetected', file_system_state='unknown', attribute='', monitor_enabled=0, monitor_period=0)
# 2022-02-06 14:53:51,682 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_state(cam_id=0, available='available', state='inactive', list_flags='')
# 2022-02-06 14:53:51,834 [INFO] 	olympe.example_media_standalone.media - _websocket_event_cb - media_event(name=indexing_state_changed)
# 2022-02-06 14:53:51,842 [INFO] 	olympe.example_media_standalone.media - _websocket_event_cb - media_event(name=indexing_state_changed)
# 2022-02-06 14:53:51,843 [INFO] 	olympe.example_media_standalone.drone - _send_command_impl - camera.take_photo(cam_id=0) has been sent to the device
# 2022-02-06 14:53:51,848 [ERROR] 	olympe.example_media_standalone.scheduler - _run_task_list - Unhandled exception in async task function
# Traceback (most recent call last):
#   File "/home/daniel/.pyenv/versions/3.8.12/envs/dp-sim/lib/python3.8/site-packages/olympe/utils/pomp_loop_thread.py", line 535, in _run_task_list
#     ret = f(*args, **kwds)
#   File "/home/daniel/.pyenv/versions/3.8.12/envs/dp-sim/lib/python3.8/site-packages/olympe/subscriber.py", line 92, in process
#     self._callback(event, self._scheduler)
#   File "/tmp/ipykernel_31172/3482113794.py", line 53, in default
#     logger.info(event)
# NameError: name 'logger' is not defined
# 2022-02-06 14:53:51,949 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.state(state='indexing')
# 2022-02-06 14:53:52,244 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.state(state='indexed')
# 2022-02-06 14:53:52,245 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.counters(video_media_count=0, photo_media_count=0, video_resource_count=0, photo_resource_count=0)
# 2022-02-06 14:53:52,251 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_state(cam_id=0, available='available', state='active', list_flags='')
# 2022-02-06 14:53:52,255 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_progress(cam_id=0, result='taking_photo', photo_count=0, media_id='', list_flags='')
# 2022-02-06 14:53:52,257 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_progress(cam_id=0, result='photo_taken', photo_count=1, media_id='', list_flags='')
# 2022-02-06 14:53:52,259 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_progress(cam_id=0, result='photo_saved', photo_count=0, media_id='10000001', list_flags='')
# 2022-02-06 14:53:52,263 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - camera.photo_state(cam_id=0, available='available', state='inactive', list_flags='')
# 2022-02-06 14:53:52,539 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - ardrone3.GPSSettingsState.GeofenceCenterChanged(latitude=48.87890000000001, longitude=2.3677785)
# 2022-02-06 14:53:52,552 [INFO] 	olympe.example_media_standalone.media - _websocket_event_cb - media_event(name=media_created, media_id=10000001, photo_mode='SINGLE')
# 2022-02-06 14:53:52,648 [INFO] 	olympe.example_media_standalone.media - _write_chunk - Download 100000010001.JPG  100% done
# 2022-02-06 14:53:52,656 [INFO] 	olympe.example_media_standalone.pdraw - _destroy_pomp_loop - Pomp loop has been destroyed: Thread-7
# 2022-02-06 14:53:52,663 [ERROR] 	olympe.example_media_standalone.scheduler - _run_task_list - Unhandled exception in async task function
# Traceback (most recent call last):
#   File "/home/daniel/.pyenv/versions/3.8.12/envs/dp-sim/lib/python3.8/site-packages/olympe/utils/pomp_loop_thread.py", line 535, in _run_task_list
#     ret = f(*args, **kwds)
#   File "/home/daniel/.pyenv/versions/3.8.12/envs/dp-sim/lib/python3.8/site-packages/olympe/subscriber.py", line 92, in process
#     self._callback(event, self._scheduler)
#   File "/tmp/ipykernel_31172/3482113794.py", line 32, in onResourceDownloaded
#     with open(event.download_path, "rb") as image_file:
# AttributeError: 'MediaEvent' object has no attribute 'download_path'
# 2022-02-06 14:53:52,786 [INFO] 	olympe.example_media_standalone.drone - _recv_cmd_cb - mediastore.counters(video_media_count=0, photo_media_count=1, video_resource_count=0, photo_resource_count=1)
# 2022-02-06 14:53:52,840 [INFO] 	olympe.example_media_standalone.pdraw - _destroy_pomp_loop - Pomp loop has been destroyed: Thread-6
# 2022-02-06 14:53:52,842 [INFO] 	olympe.example_media_standalone.drone - _disconnected_cb - Disconnected from device: ANAFI-0000000
# 2022-02-06 14:53:52,849 [INFO] 	olympe.example_media_standalone.drone - _on_device_removed - <olympe.arsdkng.cmd_itf.DisconnectedEvent object at 0x7f669b2e64c0>
# 2022-02-06 14:53:52,853 [INFO] 	olympe.example_media_standalone.scheduler - _destroy_pomp_loop - Pomp loop has been destroyed: subscribers_thread
# 2022-02-06 14:53:52,855 [INFO] 	olympe.example_media_standalone.drone - _on_device_removed - <olympe.arsdkng.cmd_itf.DisconnectedEvent object at 0x7f669b3033a0>
# 2022-02-06 14:53:52,856 [INFO] 	olympe.example_media_standalone.backend - _destroy - Manager has been destroyed
# 2022-02-06 14:53:52,859 [INFO] 	olympe.example_media_standalone.backend - _destroy_pomp_loop - Pomp loop has been destroyed: Thread-5
# <class 'olympe.media.MediaEvent'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 test_media()
#
# Input In [5], in test_media()
#       9 media = olympe.Media(
#      10     f"{DRONE_IP}:{DRONE_MEDIA_PORT}", name="example_media_standalone"
#      11 )
#      12 assert media.connect()
# ---> 13 main(drone, media)
#      14 assert media.shutdown()
#      15 assert drone.disconnect()
#
# Input In [4], in main(drone, media)
#      16         if not photo_saved.wait(_timeout=30).success():
#      17 #             logger.error("Photo not saved: {}".format(photo_saved.explain()))
#      18             print("Photo not saved: {}".format(photo_saved.explain()))
# ---> 19             return
#
# File ~/.pyenv/versions/3.8.12/envs/dp-sim/lib/python3.8/site-packages/olympe/listener.py:196, in EventListener.__exit__(self, *args, **kwds)
#     195 def __exit__(self, *args, **kwds):
# --> 196     self.unsubscribe()
#
# Input In [2], in MediaEventListener.unsubscribe(self)
#      56 self._media.wait_for_pending_downloads()
#      57 # Sanity check 1/2: md5 checksum
#      58 # The integrity check has already been performed by Olympe
#      59 # For this example the following step demonstrate how to perform the media
#      60 # integrity check afterward using the "md5summ --check *.md5" command.
# ---> 61 for resource in self._downloaded_resources:
#      62     check = subprocess.run(
#      63         ["md5sum", "--check", "{}.md5".format(resource.download_path)],
#      64         stdout=subprocess.PIPE,
#      65         cwd=os.path.dirname(resource.download_path),
#      66     )
#      67     stdout = check.stdout.decode().strip()
#
# AttributeError: 'MediaEventListener' object has no attribute '_downloaded_resources'

# %%
type(img)
# Out:
# NoneType
# 2022-02-06 14:55:57,367 [INFO] 	olympe.example_media_standalone.media - wrapper - Websocket already closed
# 2022-02-06 14:55:57,369 [ERROR] 	ulog - pomp - epoll_ctl(fd=95) err=9(Bad file descriptor)
# 2022-02-06 14:55:57,370 [ERROR] 	ulog - pomp - epoll_ctl op=2 cb=0x7f66e9b098d0 userdata=0x7f669b30d710
